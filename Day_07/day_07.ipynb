# %% [markdown]
# Day 7

# %% [markdown]
# HomeWork

# %%
import pandas as pd

data_file = 'Created_Dataset.csv'

df = pd.read_csv(data_file)

# df
# df.head(20)
# df.tail(20)
# df['loss']=df['Budget_Million_USD']-df['Revenue_Million_USD']
# df.info()
# df.describe()
# (df.index[df['Title']=='Inception'])
# print(df['Director'].unique())
# print(df['Director'].nunique())

# df[['Title', 'Director', 'Budget_Million_USD', 'Revenue_Million_USD']].head()

# filtered=df[df['Budget_Million_USD']>100].sort_values(by='Budget_Million_USD', ascending=False)
# filtered.to_csv('Big_Budget_Movies2.csv', index=False)

# df.isna()
# df.duplicated()

# df_cleaned = df.dropna().drop_duplicates()

#rank

#merge
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# dtype: bool

# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(25,6))
plt.bar(df['Genre'], df['Revenue_Million_USD'], color='purple')
# plt.plot(df['Title'], df['Revenue_Million_USD'], marker='*')
# plt.title('Line Plot')
# plt.xlabel('Movie Title')
# plt.ylabel('Revenue (Million USD)')
# plt.show()
# Out:
# <BarContainer object of 50 artists>
