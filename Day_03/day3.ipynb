# %% [markdown]
# Day 3

# %% [markdown]
# tuple

# %%
colors=("red","green","blue","yellow","black","white")

for color in colors:
    print(color)
print("")
for i in range(len(colors)):
    print(f"{i}: {colors[i]}")
# Out:
# red
# green
# blue
# yellow
# black
# white
#
# 0: red
# 1: green
# 2: blue
# 3: yellow
# 4: black
# 5: white

# %%
t=(1,2,[3,4,5])
t[2][2]=100
t[2].append(6)
print(t)
# Out:
# (1, 2, [3, 4, 100, 6])

# %%
t=(10,20,30)

temp_list=list(t)

temp_list[1]=40

t2=tuple(temp_list)

print(t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 7
#       3 temp_list=list(t)
#       5 temp_list[1]=40
# ----> 7 t2=tuple(temp_list)
#       9 print(t2)
#
# TypeError: 'tuple' object is not callable

# %%
t=(10,20,30)

temp_list=list(t)

temp_list[1]=40

t=tuple(temp_list)

print(t)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 7
#       3 temp_list=list(t)
#       5 temp_list[1]=40
# ----> 7 t=tuple(temp_list)
#       9 print(t)
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# Sets

# %%
s={1,2,3}
print(s)

l=[1,4,4,2,2,3]
se=set(l)
print(se)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4}

# %%
a={1,2,3}

l=list(a)
l=[7,8,9]
a=set(l)
print(a)
# Out:
# {8, 9, 7}
